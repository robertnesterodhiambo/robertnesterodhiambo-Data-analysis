# %% [markdown]
# This dataset contains information about used cars. It can be used for various purposes, such as price prediction to exemplify the use of linear regression in Machine Learning.
#
#
# - **name**: Name or model of the car.
# - **year**: The year the car was manufactured.
# - **selling_price**: The selling price of the car.
# - **km_driven**: The distance driven by the car in kilometers.
# - **fuel**: The type of fuel used by the car (e.g., petrol, diesel, electric).
# - **seller_type**: Type of seller (e.g., individual, dealer).
# - **transmission**: Type of transmission (e.g., manual, automatic).
# - **Owner**: Number of previous owners of the car.
#
# With this information, various analyses and machine learning models can be built to extract insights or make predictions related to used car sales. Let me know if you need further assistance with this dataset!
#
# ## Dataset Link
#
# [Link to the dataset on Kaggle](https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho)

# %% [markdown]
# # data importation
#
#
#
# 1. ```python
#    import pandas as pd
#    ```
#    This line imports the pandas library, a popular data manipulation and analysis library in Python. It is typically imported with the alias `pd` for convenience.
#
# 2. ```python
#    file_path = "CAR DETAILS FROM CAR DEKHO.csv"
#    ```
#    This line defines a variable `file_path` and assigns it the string value `"CAR DETAILS FROM CAR DEKHO.csv"`. This string represents the path to the CSV file that we want to import into our Python script.
#
# 3. ```python
#    df = pd.read_csv(file_path)
#    ```
#    This line uses the `read_csv()` function from pandas to read the CSV file specified by `file_path` into a pandas DataFrame. The resulting DataFrame is assigned to the variable `df`.
#
# 4. ```python
#    print(df.head())
#    ```
#    This line prints the first few rows of the DataFrame `df` using the `head()` method. By default, `head()` displays the first 5 rows of the DataFrame. This allows you to quickly inspect the contents of the DataFrame after reading the CSV file.

# %%
import pandas as pd

# Specify the file path
file_path = "CAR DETAILS FROM CAR DEKHO.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %% [markdown]
# # data cleannig
#
# We use select_dtypes(include=['int', 'float']) to select only the columns with numeric data types (integer or float) from the original DataFrame df.
# The selected columns are assigned to the new DataFrame df_int.
# Finally, we print the first few rows of the new DataFrame df_int to verify the result.

# %%
# Select only the columns with numeric (integer or float) data types
df_int = df.select_dtypes(include=['int', 'float'])
df_int
# Out:
#       year  selling_price  km_driven
# 0     2007          60000      70000
# 1     2007         135000      50000
# 2     2012         600000     100000
# 3     2017         250000      46000
# 4     2014         450000     141000
# ...    ...            ...        ...
# 4335  2014         409999      80000
# 4336  2014         409999      80000
# 4337  2009         110000      83000
# 4338  2016         865000      90000
# 4339  2016         225000      40000
#
# [4340 rows x 3 columns]

# %% [markdown]
# # visualisation
#
#
# 1. **Value counts for fuel:**
#    - This table shows the distribution of different types of fuels used by cars in the dataset.
#    - Diesel and petrol are the most common types of fuel, which aligns with real-world trends as these are widely used in internal combustion engine vehicles.
#    - CNG (Compressed Natural Gas) and LPG (Liquefied Petroleum Gas) are alternative fuel options that are less common but still present in the dataset. They are often chosen for their lower cost and environmental benefits.
#    - The presence of an electric vehicle (EV) in the dataset reflects the growing trend towards electric mobility, driven by concerns about air pollution and climate change.
#
# 2. **Value counts for seller_type:**
#    - This table shows the distribution of different types of sellers offering cars for sale in the dataset.
#    - "Individual" sellers are the most common, indicating that many cars are sold by private owners. This reflects the prevalence of private transactions in the used car market, where individuals sell their own vehicles.
#    - "Dealer" sellers represent professional car dealerships, which are also common in the market. Dealerships offer a wide range of services such as warranties, financing, and vehicle inspections.
#    - "Trustmark Dealer" sellers are likely certified dealerships with a reputation for reliability and quality. Buyers may prefer purchasing from trustmark dealers for added assurance and peace of mind.
#
# 3. **Value counts for transmission:**
#    - This table shows the distribution of different types of transmissions in the dataset.
#    - "Manual" transmissions are more common, which is typical in many regions, especially in countries where manual transmission vehicles are popular due to lower cost, better fuel efficiency, and greater control.
#    - "Automatic" transmissions are also significant, reflecting the increasing popularity of automatic vehicles, particularly in urban areas with heavy traffic. Automatic transmissions offer convenience and ease of use, especially in stop-and-go driving conditions.
#
# 4. **Value counts for owner:**
#    - This table shows the distribution of the number of previous owners for cars in the dataset.
#    - "First Owner" cars are the most common, indicating that many cars being sold are relatively new or have only had one previous owner. Buyers often prefer first-owner cars because they typically have lower mileage and are in better condition.
#    - "Second Owner" cars are also common, reflecting the natural progression of vehicle ownership. Second-owner cars may offer good value for buyers seeking slightly used vehicles at a lower price.
#    - "Third Owner" and "Fourth & Above Owner" cars represent vehicles that have had multiple owners. These cars may have higher mileage and more wear and tear, leading to lower resale value. Buyers may consider factors such as maintenance history and condition when purchasing these cars.
#    - "Test Drive Car" likely refers to vehicles used for test drives by dealerships or manufacturers. These cars are typically low-mileage and well-maintained, serving as demonstration vehicles for potential buyers.
#
#
# - The "year" column represents the manufacturing year of the cars in the dataset.
# - The table provides a count of how many cars were manufactured in each year.
#
# **Key Observations:**
# 1. **Distribution of Manufacturing Years:**
#    - The majority of cars in the dataset were manufactured between the years 2000 and 2020, with a concentration around the mid-2000s to the late 2010s.
#    - The highest counts are observed for the years 2017, 2015, and 2012, indicating that cars from these years are more prevalent in the dataset.
#    - This distribution reflects the typical age range of used cars available in the market, with a mix of relatively recent models from the past decade as well as older models from the late 1990s and early 2000s.
#
# 2. **Trend in Recent Years:**
#    - There is a noticeable increase in the number of cars manufactured in the most recent years (2018, 2019, and 2020), albeit with lower counts compared to earlier years.
#    - This trend suggests that newer cars are entering the used car market, possibly due to factors such as increased turnover of vehicle ownership, lease returns, and new car sales.
#
# 3. **Variability in Older Years:**
#    - The counts gradually decrease as we move further back in time, with fewer cars manufactured in the early 2000s and even fewer from the late 1990s and earlier.
#    - This variability in counts for older years is expected, as older cars may have been retired from active use, scrapped, or become less common in the used car market due to factors such as age, condition, and technological advancements.
#
# **Implications:**
# - The distribution of manufacturing years provides insights into the composition of the dataset and the availability of cars from different time periods in the used car market.
# - Buyers and sellers can use this information to make informed decisions about pricing, demand, and preferences based on the age of the vehicles.
# - Dealerships and manufacturers can also use this data to analyze market trends, forecast demand for specific model years, and plan inventory management strategies.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Iterate over each column in the DataFrame
for column in df.columns:
    # Create a bar plot for the current column
    df[column].value_counts().plot(kind='bar', figsize=(10, 15))
    
    # Set plot title and labels
    plt.title(f'Bar Plot for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    # Show the plot
    plt.show()

# %%
import pandas as pd

# Iterate over each column in the DataFrame
for column in df.columns:
    # Print the value counts of the current column
    print(f"Value counts for {column}:")
    print(df[column].value_counts())
    print("\n")
# Out:
# Value counts for name:
# name
# Maruti Swift Dzire VDI                     69
# Maruti Alto 800 LXI                        59
# Maruti Alto LXi                            47
# Maruti Alto LX                             35
# Hyundai EON Era Plus                       35
#                                            ..
# Hyundai Verna Transform CRDi VGT SX ABS     1
# Maruti S-Presso VXI Plus                    1
# Toyota Etios Liva 1.2 VX                    1
# Toyota Yaris G                              1
# Hyundai i20 Magna 1.4 CRDi                  1
# Name: count, Length: 1491, dtype: int64
#
#
# Value counts for year:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# ...

# %% [markdown]
# # linear regression model
#
# **Description of the Model:**
# - The chosen model is simple linear regression. It assumes a linear relationship between the features (independent variables) and the target variable (dependent variable).
# - The model's equation is: Y = β0 + β1*X1 + β2*X2 + ... + βn*Xn, where Y is the target variable, X1, X2, ..., Xn are the features, and β0, β1, β2, ..., βn are the coefficients.
# - The model fits a line to the data that minimizes the sum of the squared differences between the observed and predicted values.
#
# **Assumptions of Linear Regression:**
# 1. **Linearity:** The relationship between the features and the target variable is linear.
# 2. **Independence:** The observations are independent of each other.
# 3. **Homoscedasticity:** The variance of the errors is constant across all levels of the target variable.
# 4. **Normality of Residuals:** The residuals (errors) are normally distributed.
# 5. **No Multicollinearity:** The features are not highly correlated with each other.
#
# **Hyperparameters:**
# - In this example, no hyperparameters are explicitly set for the linear regression model. However, the `LinearRegression` class in scikit-learn has parameters such as `fit_intercept` (whether to calculate the intercept) and `normalize` (whether to normalize the features).
#
# This code demonstrates how to implement a simple linear regression model using the DataFrame `df_int`, with the 'selling_price' as the target variable (`Y`). Adjustments and enhancements can be made based on the specific requirements of your dataset and model performance evaluation. Let me know if you need further clarification or assistance!

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Load the DataFrame
# Assuming df_int contains the features and target variable
# X represents the features, Y represents the target variable
X = df_int.drop(columns=['selling_price'])
Y = df_int['selling_price']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Initialize the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, Y_train)

# Predict on the testing data
Y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(Y_test, Y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 255707328588.5748

# %% [markdown]
# # model explaintions
#
#
# \[ Y = \beta_0 + \beta_1 \cdot X_1 \]
#
# where:
# - \( Y \) is the dependent variable (in this case, the 'selling_price').
# - \( X_1 \) is the independent variable (in this case, 'year').
# - \( \beta_0 \) is the intercept term.
# - \( \beta_1 \) is the coefficient for the independent variable.
#
# From the coefficients you provided:
# - The coefficient for 'year' (\( \beta_1 \)) is approximately 56424.64.
# - The coefficient for 'km_driven' (\( \beta_2 \)) is approximately -0.31724.
# - The intercept term (\( \beta_0 \)) is approximately -113060685.31.
#
# The equation for your linear regression model would be:
#
# \[ \text{selling\_price} = -113060685.31 + 56424.64 \cdot \text{year} - 0.31724 \cdot \text{km\_driven} \]
#
# This equation allows you to predict the selling price (\( Y \)) based on the values of 'year' and 'km_driven'. The coefficients indicate the impact of each independent variable on the dependent variable. In this case, the positive coefficient for 'year' suggests that as the manufacturing year increases, the selling price is expected to increase. The negative coefficient for 'km_driven' suggests that as the distance driven increases, the selling price is expected to decrease.

# %%
import matplotlib.pyplot as plt

# Choose a specific feature column from X_test
feature_column = 'year'  # Replace 'year' with the desired feature column

# Plot the linear regression model
plt.figure(figsize=(10, 6))
plt.scatter(X_test[feature_column], Y_test, color='blue', label='Actual')
plt.plot(X_test[feature_column], Y_pred, color='red', label='Predicted')
plt.title('Linear Regression Model')
plt.xlabel(feature_column)
plt.ylabel('Selling Price')
plt.legend()
plt.show()

# Display model coefficients and intercept
print("Model Coefficients:")
for feature, coefficient in zip(X.columns, model.coef_):
    print(f"{feature}: {coefficient}")

print("\nIntercept:", model.intercept_)
# Out:
# Model Coefficients:
# year: 56424.63840314591
# km_driven: -0.31724066512753746
#
# Intercept: -113060685.31157923
