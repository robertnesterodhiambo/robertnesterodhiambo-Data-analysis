# %% [markdown]
# # Vizualizations
#
# var A against Var B.
#
# ![image.png](attachment:image.png)
#
# Explaining what it means from the output.

# %%
print("My name sid is dragon")
# Out:
# My name sid is dragon
