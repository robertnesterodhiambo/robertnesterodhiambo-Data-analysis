# %%
import subprocess

# List of additional packages to install
additional_packages = [
    "numpy",
    "pandas",
    "matplotlib",
    "seaborn",
    "nltk",
    "gensim",
    "scipy",
    "statsmodels",
    "torch",
    "keras"
]

# Install each additional package
for package in additional_packages:
    subprocess.call(['pip', 'install', package])
